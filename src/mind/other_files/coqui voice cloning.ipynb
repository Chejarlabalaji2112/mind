# %%
from TTS.api import TTS
import torch

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to("cuda")

# Extract embedding from your WAV
embedding = tts.speaker_manager.compute_embedding_from_clip("/home/badri/mine/hitomi/mind/src/mind/assets/japanese_audio.mp3")

# Save speaker embedding
torch.save(embedding, "/home/badri/mine/hitomi/mind/src/mind/assets/my_voice_embedding.pt")
# Out:
# Running cells with 'hitomi_3_11 (Python 3.11.14)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
